# %% [markdown]
# # Example notebook
#
# This is a Markdown cell. It can include math like $x^2 = 1$ or
# $$ \int_a^b f(x)\, dx = \lim_{n \to \infty}  \frac{b - a}{n} \sum_{i=1}^n f(x_i^*). $$
#
# Below is a code cell:

# %%
#| label: calc
2 + 2
# Out:
# 4

# %% [raw]
# This is a raw cell.
# Let's write a Typst equation: $QQ = { p/q : p in ZZ, q in NN }$.

# %%
#| label: plot1
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.figsize'] = (3, 2)
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('x square')
plt.show()

# %%
#| label: plot2
plt.plot([1, 2, 3, 4], [1, 3, 7, 3])
2**10
# Out:
# 1024

# %% [markdown]
# A cell with several display objects:

# %%
#| label: plot3
#| type: lines
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()
plt.plot([1, 2, 3, 4], [1, 3, 7, 3]);

# %% [markdown]
# A cell that produces math formulas:

# %%
#| label: some-math
import sympy as sp
x, i, n = sp.symbols('x,i,n')
sp.Sum(x**i, (i, 1, n))
# Out:
# Sum(x**i, (i, 1, n))

# %% [markdown]
# A cell that produces a JSON object:

# %%
#| label: json-result
from IPython.display import display, JSON
some_dict = {
  'a': 0,
  's': 'some string',
}
JSON(some_dict)

# %% [markdown]
# A cell that produces an error:

# %%
#| label: type-error
[1] + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #| label: type-error
# ----> 2 [1] + 2
#
# TypeError: can only concatenate list (not "int") to list
