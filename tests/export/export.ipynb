# %%
x = 1 + 2; x
# Out:
# 3

# %%
x += 1; x
# Out:
# 4

# %%
x += 1; x
# Out:
# 5

# %%
# | label: x
# | output: false
2 + 3
# Out:
# 5

# %%
# | echo: false
3 + 4
# Out:
# 7

# %%
10 + 1
# Out:
# 11

# %%
10 + 2
# Out:
# 12

# %%
10 + 3
# Out:
# 13

# %%
a = 23; a
# Out:
# 23

# %%
b = 42; b
# Out:
# 42

# %%
c = 91; c
# Out:
# 91

# %%
3*3
# Out:
# 9

# %%
3*3
# Out:
# 9

# %%
3*3
# Out:
# 9

# %%
4*4
# Out:
# 16

# %%
5*5
# Out:
# 25

# %%
# | dedup: 2
4*4
# Out:
# 16

# %%
# | dedup: 2
5*5
# Out:
# 25
