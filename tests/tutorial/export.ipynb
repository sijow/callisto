# %%
# | label: pandas-setup
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

# %%
3+3
# Out:
# 6

# %%
# | label: square
3+3
# Out:
# 6

# %%
import random
random.randint(0, 6)
# Out:
# 1

# %%
# | echo: false
2 + 3
# Out:
# 5

# %%
# | label: calc
# | output: false
2 + 3
# Out:
# 5

# %%
2 + 3
# Out:
# 5

# %%
2 + 4
# Out:
# 6

# %%
3*3
# Out:
# 9

# %%
2+3
# Out:
# 5
